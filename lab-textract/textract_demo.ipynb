# %% [markdown]
# # Detecting headers and footers using Amazon Textract
#
# A common customer use case when extracting text from documents is to identify, and in many cases ignore, headers and footers. Textract provides sufficient metadata to make this possible. Note this sample just demonstrates a simple version of the use case, and is not meant to provide a general purpose out of the box solution.
#
# Before running this notebook:
#
# 1. Upload the sample PDF document into an S3 bucket
# 2. Define an SNS topic that will receive a notification of completion of the async text detection job
# 3. Define an SNS role that Textract can use to access the SNS topic

# %%
import boto3

# To call the start_document_text_detection api, need to have an SNS topic and role defined
BUCKET    = '<YOUR BUCKET NAME HERE>'

# If you placed the PDF file in a different prefix in your S3 bucket, update PREFIX
PREFIX    = 'textract/test_input/'

# If you used a different PDF filename, update FILENAME
FILENAME  = PREFIX + 'sample_with_headers.pdf'

# Capture your SNS topic and role arn's here
SNS_TOPIC = '<YOUR SNS TOPIC ARN HERE>'
SNS_ROLE  = '<YOUR SNS ROLE ARN HERE>'

client = boto3.client('textract')

# %%
doc_loc       = {'S3Object': {'Bucket': BUCKET, 'Name': FILENAME}} 
notif_channel = {'SNSTopicArn': SNS_TOPIC, 'RoleArn': SNS_ROLE}

response = client.start_document_text_detection(
    DocumentLocation=doc_loc,
    JobTag='1',
    NotificationChannel=notif_channel
)
response
# Out:
# {'JobId': 'a79704d403a47d45c1b0d2f0f33beba20c6920e169c3f132b05ba0b9e41a2b88',
#  'ResponseMetadata': {'RequestId': 'cf39c7c4-ff01-4564-b475-2568388afe87',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Fri, 26 Apr 2019 18:07:46 GMT',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '76',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'cf39c7c4-ff01-4564-b475-2568388afe87'},
#   'RetryAttempts': 0}}

# %%
job_id = response['JobId']

# %%
job_id
# Out:
# 'a79704d403a47d45c1b0d2f0f33beba20c6920e169c3f132b05ba0b9e41a2b88'

# %%
response = client.get_document_text_detection(
    JobId=job_id,
    MaxResults=500
)

job_status = response['JobStatus']
if (job_status == 'SUCCEEDED'):
    next_token = response['NextToken']
    blocks = response['Blocks']
    print('Job SUCCEEDED, returned {} blocks'.format(len(blocks)))
else:
    print('Job status: ' + job_status)
    
# retry until job is completed (succeeded) vs in progress
# Out:
# Job SUCCEEDED, returned 500 blocks

# %%
response
# Out:
# {'DocumentMetadata': {'Pages': 5},
#  'JobStatus': 'SUCCEEDED',
#  'NextToken': 'bWhL0lel3REElcoozHWS/WSUKLth6Mx/wSCYsDvppbHUW82AbTknjN4fYXqKZOmw5BEMZrIlBjH7qbYIeqTTWNGZW/pa/wdJBcSJ6/PT65sO9DQd',
#  'Blocks': [{'BlockType': 'PAGE',
#    'Geometry': {'BoundingBox': {'Width': 1.0,
#      'Height': 1.0,
#      'Left': 0.0,
#      'Top': 0.0},
#     'Polygon': [{'X': 0.0, 'Y': 0.0},
#      {'X': 1.0, 'Y': 0.0},
#      {'X': 1.0, 'Y': 1.0},
#      {'X': 0.0, 'Y': 1.0}]},
#    'Id': '691b5dd0-3d66-4617-808d-3c7521ae137f',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['e452d817-aae0-4fb6-9db6-cc3fa998c69c',
#       '2a233469-36b7-43f2-a6c7-b00840da9af6',
#       '4b896554-d31d-4f3d-b808-a577c549711f',
#       '41688818-cf48-46dc-a2f7-a92a8b3fc673',
#       '76d7daf9-280e-409c-9ede-dda1e93a4f7f',
#       '48c4368e-2b88-43d2-9eaf-841acb4d3890',
#       '44329fa8-d14c-4c8a-a55b-9967c05af330',
']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 98.57797241210938,
#    'Text': 'Add headers and footers, with no document open (Windows only)',
#    'Geometry': {'BoundingBox': {'Width': 0.5038437843322754,
#      'Height': 0.016062863171100616,
#      'Left': 0.08676828444004059,
#      'Top': 0.12072531133890152},
#     'Polygon': [{'X': 0.08676828444004059, 'Y': 0.12072531133890152},
#      {'X': 0.5906120538711548, 'Y': 0.12072531133890152},
#      {'X': 0.5906120538711548, 'Y': 0.13678817451000214},
#      {'X': 0.08676828444004059, 'Y': 0.13678817451000214}]},
#    'Id': '76d7daf9-280e-409c-9ede-dda1e93a4f7f',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['3e077118-a0b8-41e5-b787-235f30b8803d',
#       '054dc541-6644-420c-879c-bf505377f19a',
#       '750cde24-37e6-4351-b3f8-d272f66f48ca',
#       '5d564843-3b04-4465-a488-e0df623d16cd',
#       '817fbbef-e0aa-4f14-a872-3ec89670713b',
#       '45af9726-1314-4b4f-80c0-10f4804dce76',
#       '301dc302-6023-4aae-ab12-444266b898d9',
#       'a1bb8147-2e3b-4791-a65c-bea4d54d26dc',
#       'fde50fc1-f748-4710-860b-818e5ae55052',
#       'fd1d44b0-9223-4733-ba15-12bb6a2a552c']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 99.46475982666016,
#    'Text': 'Update the headers and footers',
#    'Geometry': {'BoundingBox': {'Width': 0.24052932858467102,
#      'Height': 0.014580836519598961,
#      'Left': 0.0869988203048706,
#      'Top': 0.1434086263179779},
#     'Polygon': [{'X': 0.0869988203048706, 'Y': 0.1434086263179779},
#      {'X': 0.3275281488895416, 'Y': 0.1434086263179779},
#      {'X': 0.3275281488895416, 'Y': 0.1579894721508026},
#      {'X': 0.0869988203048706, 'Y': 0.1579894721508026}]},
#    'Id': '48c4368e-2b88-43d2-9eaf-841acb4d3890',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['f03ea2d9-0ae9-4c2e-9012-c4b43e6a18f3',
#       'e73a8b4c-53b4-4d94-b3e6-41f4dc82960f',
#       'd2e04e5c-860a-4e8e-b50d-43512f53fe28',
#       '3af41687-5000-4917-aacf-d6b58d620a3c',
#       '11bd660b-adea-4aa1-9876-93f518af36e9']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 99.23744201660156,
#    'Text': 'Add another header and footer',
#    'Geometry': {'BoundingBox': {'Width': 0.23601627349853516,
#      'Height': 0.014847004786133766,
#      'Left': 0.08651790022850037,
#      'Top': 0.1649623066186905},
#     'Polygon': [{'X': 0.08651790022850037, 'Y': 0.1649623066186905},
#      {'X': 0.3225341737270355, 'Y': 0.1649623066186905},
#      {'X': 0.3225341737270355, 'Y': 0.1798093169927597},
#      {'X': 0.08651790022850037, 'Y': 0.1798093169927597}]},
#    'Id': '44329fa8-d14c-4c8a-a55b-9967c05af330',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['a0fdb538-bb41-4389-9fbf-5dfafada3c7b',
#       '2e54a69e-ed73-43ff-9ec4-328035bd9d72',
#       'bf6f9005-7e04-400d-aa1a-27d9d61bab39',
#       'f1e75a84-951f-425a-97e6-1bc6b8f9bef3',
#       'f3c0d39f-0dcd-4dd6-aba1-a58c2159794c']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 99.32805633544922,
#    'Text': 'Replace all headers and footers',
#    'Geometry': {'BoundingBox': {'Width': 0.23874936997890472,
#      'Height': 0.015479699708521366,
#      'Left': 0.08715663850307465,
#      'Top': 0.1871183216571808},
#     'Polygon': [{'X': 0.08715663850307465, 'Y': 0.1871183216571808},
#      {'X': 0.32590600848197937, 'Y': 0.1871183216571808},
#      {'X': 0.32590600848197937, 'Y': 0.20259802043437958},
#      {'X': 0.08715663850307465, 'Y': 0.20259802043437958}]},
#    'Id': '378fb05b-589a-4681-ba58-346e55c0302b',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['7ac81e03-376c-40b3-8191-e570b557c10c',
#       '81e726a0-2189-4014-b56a-6566bc539043',
#       '6c9b4c8e-5a21-42e6-97c6-7c60d1c53809',
#       '42757582-90c2-41ce-8be5-e6c00325e346',
#       'c28a7a02-9fb9-4d06-a6db-37a1c7ec7bbf']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 99.05120849609375,
#    'Text': 'Remove all headers and footers',
#    'Geometry': {'BoundingBox': {'Width': 0.2403358817100525,
#      'Height': 0.014545362442731857,
#      'Left': 0.08762449026107788,
#      'Top': 0.20925980806350708},
#     'Polygon': [{'X': 0.08762449026107788, 'Y': 0.20925980806350708},
#      {'X': 0.32796037197113037, 'Y': 0.20925980806350708},
#      {'X': 0.32796037197113037, 'Y': 0.22380517423152924},
#      {'X': 0.08762449026107788, 'Y': 0.22380517423152924}]},
#    'Id': '70216932-1259-4a81-8bfe-7f72221deb59',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['2274764d-0ac1-4329-86e3-45b641499154',
#       '5ee24f54-e2e8-4694-afd1-f7da9d79da08',
#       '981a3bbd-1f0b-41bb-97cf-a0e79dbc514a',
#       'd6676d64-9355-4ef7-b0f4-6ff2c2973c95',
#       '274dd67e-c58b-465f-b0c3-6693936695df']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 96.5987319946289,
#    'Text': 'Show all',
#    'Geometry': {'BoundingBox': {'Width': 0.056639429181814194,
#      'Height': 0.015441968105733395,
#      'Left': 0.10167492181062698,
#      'Top': 0.23174645006656647},
#     'Polygon': [{'X': 0.10167492181062698, 'Y': 0.23174645006656647},
#      {'X': 0.15831434726715088, 'Y': 0.23174645006656647},
#      {'X': 0.15831434726715088, 'Y': 0.24718841910362244},
#      {'X': 0.10167492181062698, 'Y': 0.24718841910362244}]},
#    'Id': '6ea343ea-624c-4f65-8f4c-c7a931466c0f',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['9324bc9f-bc6b-4cbc-8f29-c032f18fe2f4',
#       'a34ce4c2-2765-4903-b2fb-af21a4057b82']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 97.88920593261719,
#    'Text': 'To the top',
#    'Geometry': {'BoundingBox': {'Width': 0.06469793617725372,
#      'Height': 0.013204197399318218,
#      'Left': 0.7865203022956848,
#      'Top': 0.26670369505882263},
#     'Polygon': [{'X': 0.7865203022956848, 'Y': 0.26670369505882263},
#      {'X': 0.8512182235717773, 'Y': 0.26670369505882263},
#      {'X': 0.8512182235717773, 'Y': 0.27990788221359253},
#      {'X': 0.7865203022956848, 'Y': 0.27990788221359253}]},
#    'Id': 'c013bd50-a346-4697-84fa-46bf8df5fa1e',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['6c73ee5d-9684-48d4-855a-b345f64dc609',
#       '567b69fc-9608-48b5-bc7a-b7446db8ea77',
#       'c8bce30f-1ac3-4cac-8d38-f04e41be3473']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 99.22080993652344,
#    'Text': 'Headers, footers, and Bates numbering',
#    'Geometry': {'BoundingBox': {'Width': 0.3811913728713989,
#      'Height': 0.02353469468653202,
#      'Left': 0.0871114656329155,
#      'Top': 0.29826825857162476},
#     'Polygon': [{'X': 0.0871114656329155, 'Y': 0.29826825857162476},
#      {'X': 0.468302845954895, 'Y': 0.29826825857162476},
#      {'X': 0.468302845954895, 'Y': 0.32180294394493103},
#      {'X': 0.0871114656329155, 'Y': 0.32180294394493103}]},
#    'Id': 'f7088506-b984-4f3e-bf08-739bfc04d730',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['

#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['65804597-959f-4183-928c-8fd52913f238',
#       '45b7ac52-17e7-4032-b196-3af0b8bb64ae',
#       '2242d7e0-b35a-4726-97dd-f2410c58b99f',
#       'b80bb724-60da-4997-bf22-db803c217d61',
#       '9693a425-7b04-417a-84f4-6757fbdf75c6',
#       'e82481c5-a1aa-4425-9a09-aaa6b3cdb5fc',
#       '4cb68099-c185-42f8-9383-3cc20307596b',
#       '4c266438-91eb-4781-bd02-3042b935a0be',
#       '4d2a67d9-eef8-434b-86ba-235a1676e786',
#       'db0204a7-df3a-454c-ae40-817e46bb13ca',
#       '8b5c9168-8219-44cd-84f6-bb0a41dfdc9a',
#       'd83712d2-d69c-47bb-87ee-11e2c51721ba',
#       '2f033c97-01b7-49e2-8448-3b375561111a',
#       'd160c44b-c9fb-4084-a2b2-5698a7eff97f',
#       '01887a22-3d56-480f-9d31-ac6f156719d5',
#       '520d39e4-9e2a-4b76-a43b-7a71c4dd7610']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 98.64022064208984,
#    'Text': 'headers and footers to one or more PDFS.',
#    'Geometry': {'BoundingBox': {'Width': 0.30567994713783264,
#      'Height': 0.015215250663459301,
#      'Left': 0.08648792654275894,
#      'Top': 0.37337756156921387},
#     'Polygon': [{'X': 0.08648792654275894, 'Y': 0.37337756156921387},
#      {'X': 0.392167866230011, 'Y': 0.37337756156921387},
#      {'X': 0.392167866230011, 'Y': 0.38859283924102783},
#      {'X': 0.08648792654275894, 'Y': 0.38859283924102783}]},
#    'Id': 'e5567a57-7d61-4b26-875d-0ad91e02c83f',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['ac3d6a81-034f-45b3-8bc9-47fe4932b4fa',
#       '375ebb55-a92a-41f1-b2a9-4a0517110331',
#       'b488cd99-51a5-40cd-9bf4-cd40d4af2d4b',
#       '0f3e612b-1117-4c87-b95d-06a47cfd4a7c',
#       '20a6c773-434f-4297-979e-916a045c7bb3',
#       'b74be0a3-8d95-4bcd-913e-7203abc1d9eb',
#       '036231ee-780e-4eaf-bd42-84855fcbefa6',
#       '7083c494-f6af-4f87-bc81-5503a4fd01a4']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 98.33950805664062,
#    'Text': 'You can vary the headers and footers within a PDF. For example, you can add a header that displays the',
#    'Geometry': {'BoundingBox': {'Width': 0.756668746471405,
#      'Height': 0.015843283385038376,
#      'Left': 0.0862232968211174,
#      'Top': 0.39922264218330383},
#     'Polygon': [{'X': 0.0862232968211174, 'Y': 0.39922264218330383},
#      {'X': 0.842892050743103, 'Y': 0.39922264218330383},
#      {'X': 0.842892050743103, 'Y': 0.4150659143924713},
#      {'X': 0.0862232968211174, 'Y': 0.4150659143924713}]},
#    'Id': '07058dd2-eaa5-40c8-a0a0-1fd002dd20e2',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['fd052211-6f07-4625-8d28-13785a124af5',
#       '6927bce2-5279-4b82-9458-2393b55b2c9a',
#       'bb4d8447-1825-41c7-9c3c-d247e7d84f90',
#       'cf32025a-0dd5-42ff-bdd9-491b696fe206',
#       '38d00c76-d69f-477d-9e81-6f5b8c490a57',
#       'f5e6c96d-b01d-41da-b515-cc1141a2347a',
#       'a0fc6fdf-369a-463e-b095-5e44d588e4b3',
#       'f92001a7-594c-43e6-b3ff-6b42fab8fc4a',
#       'f9e4704e-5d5d-451c-9dea-3723a220969d',
#       'edabc936-868b-4191-8ca6-7e3650b4fb70',
#       '817bcd41-b4b0-4116-aa7f-8f9a9f105a7d',
#       '4003f6b4-31e2-4bb3-b33c-3c3556a0b28e',
#       '76338a34-3030-46e2-aa45-4aec8cda857f',
#       '46fac82e-f115-43f9-a4e4-431474819032',
#       'cf88ec59-7048-4848-88d0-9e2fe2ad2403',
#       '3d33121d-3b13-4ead-ab1f-5ba15918a354',
#       '79e37dc6-42da-4cbd-87b4-b0647c7c0ed9',
#       '1179df48-60ea-4f18-b075-3ffeece1fb05',
#       'df592a9c-a972-4111-9846-d6c8091b028e',
#       'c3caf33a-ed59-482b-b663-5e982d4a8510']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 99.07243347167969,
#    'Text': 'page number on the right side of odd-numbered pages, and another header that displays the page number',
#    'Geometry': {'BoundingBox': {'Width': 0.7809959650039673,
#      'Height': 0.016126006841659546,
#      'Left': 0.08711503446102142,
#      'Top': 0.41718408465385437},
#     'Polygon': [{'X': 0.08711503446102142, 'Y': 0.41718408465385437},
#      {'X': 0.8681110143661499, 'Y': 0.41718408465385437},
#      {'X': 0.8681110143661499, 'Y': 0.4333100914955139},
#      {'X': 0.08711503446102142, 'Y': 0.4333100914955139}]},
#    'Id': '878efe76-9b0a-484b-81ce-d8828b4a881b',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['a96262f2-212c-4687-9b40-4c0d19bb903a',
#       '5af3db03-0ded-48e7-bcc4-16e1599dec2f',
#       'e8e99627-5332-448a-bae0-03b27e673260',
#       '3078f2f4-8845-4e7a-ab37-13ca1fe38f34',
#       '78d16fa9-90c0-4048-872c-10d4822bbc3f',
#       'a55593eb-0e4c-4806-a0fc-b0ab5faada37',
#       '824471b3-14c1-4397-a76f-49ea43cad383',
#       '31900852-8ab1-4de9-998c-6772ff6e8e69',
#       '5112aac8-1978-4bd8-bd15-5e3644bd2b9c',
#       '036b3bb9-7b54-4b17-a36c-6432ea36ee93',
#       '2ae22883-ad78-4585-a519-bb335cbae311',
#       '49543d49-91f8-4bfb-87ca-db5b1cd3b706',
#       'a567e688-3fd2-424d-b5bc-bfe1193d3850',
#       '410c69eb-c141-49ad-bde9-6f9e3909c32f',
#       '97eb73d8-38ed-43f1-a12d-80651d264413',
#       '38a486fe-27ad-439f-88d0-cd19e7d2e91e',
#       '0d61c051-0587-497d-869b-648824817a5c']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 94.71253204345703,
#    'Text': 'on',
#    'Geometry': {'BoundingBox': {'Width': 0.01829676516354084,
#      'Height': 0.014599017798900604,
#      'Left': 0.08723559230566025,
#      'Top': 0.4358665645122528},
#     'Polygon': [{'X': 0.08723559230566025, 'Y': 0.4358665645122528},
#      {'X': 0.10553235560655594, 'Y': 0.4358665645122528},
#      {'X': 0.10553235560655594, 'Y': 0.4504655599594116},
#      {'X': 0.08723559230566025, 'Y': 0.4504655599594116}]},
#    'Id': 'adde7267-2e0e-43e1-bf49-72c857157e03',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['c9f43892-c9f8-47dd-994a-dd6746577da7']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 98.77391815185547,
#    'Text': 'the left side of numbered pages. When adding Bates numbering, you can set the number of digits,',
#    'Geometry': {'BoundingBox': {'Width': 0.7559982538223267,
#      'Height': 0.016300788149237633,
#      'Left': 0.11027953028678894,
#      'Top': 0.4350017309188843},
#     'Polygon': [{'X': 0.11027953028678894, 'Y': 0.4350017309188843},
#      {'X': 0.8662777543067932, 'Y': 0.4350017309188843},
#      {'X': 0.8662777543067932, 'Y': 0.45130252838134766},
#      {'X': 0.11027953028678894, 'Y': 0.45130252838134766}]},
#    'Id': '9cbe0703-8f9e-4296-b263-be98897f246b',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['
}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 98.56546783447266,
#    'Text': 'You can define and save your headers and footers to reuse them later, or you can simply apply a header',
#    'Geometry': {'BoundingBox': {'Width': 0.7577205300331116,
#      'Height': 0.01720532961189747,
#      'Left': 0.08595917373895645,
#      'Top': 0.4784112274646759},
#     'Polygon': [{'X': 0.08595917373895645, 'Y': 0.4784112274646759},
#      {'X': 0.8436797261238098, 'Y': 0.4784112274646759},
#      {'X': 0.8436797261238098, 'Y': 0.4956165552139282},
#      {'X': 0.08595917373895645, 'Y': 0.4956165552139282}]},
#    'Id': '5a5f5aad-4399-4d94-9749-3f0c56379308',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['27d6215c-45a6-4e2e-ba8a-79d2ef191f54',
#       '404c4202-2816-43e7-a8fb-e4456cfd79b1',
#       '4de56cfe-19ef-44d8-992d-227752e48b11',
#       '9e971a1c-d5f9-481c-9542-6cc4d87ec931',
#       'dbb88d89-01f9-4ff2-b464-48c841e73705',
#       'cc6cc890-c235-4c0b-8352-7767ec3c068e',
#       '84c0a412-09d2-4082-9984-5c6199e84fc7',
#       '9aeefd95-c8e8-430e-b4d3-b98a651db466',
#       'e870bba3-22ad-4594-9cb8-289def336772',
#       '2ad6bc97-747c-4195-bd18-448471b70a43',
#       '75a8b5f5-fd01-469f-8073-fa3e6cc7f11d',
#       '674f330d-4671-42ec-8cd2-72f38e93db00',
#       'a4980ae1-0ae9-4aa8-87a9-34603586f075',
#       '5029c76b-f415-413f-b2e5-8c2202b45a4b',
#       'af79e6b1-1bc2-487d-8983-9a990014e03b',
#       '7ea02abc-739f-4381-a254-dd5341647240',
#       '8a9d544b-26a9-4d97-8763-e8ddc6a7bf2d',
#       '272fe34f-35d5-4bcd-97bb-072dc08272fd',
#       '2835b5ba-1b13-4c10-a80e-35152e1e13e8',
#       'f0261c75-50da-4aa0-af92-f3cae443af0b']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 98.61466979980469,
#    'Text': 'and footer and forget it. After applying a header and footer, you can edit, replace, or delete it in the PDF.',
#    'Geometry': {'BoundingBox': {'Width': 0.7557815909385681,
#      'Height': 0.016314920037984848,
#      'Left': 0.08688507229089737,
#      'Top': 0.49767667055130005},
#     'Polygon': [{'X': 0.08688507229089737, 'Y': 0.49767667055130005},
#      {'X': 0.8426666855812073, 'Y': 0.49767667055130005},
#      {'X': 0.8426666855812073, 'Y': 0.5139915943145752},
#      {'X': 0.08688507229089737, 'Y': 0.5139915943145752}]},
#    'Id': '9e34390e-db30-47d5-9e45-b1502bba9fd5',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['5f053a73-6e48-4289-bf3b-6e61574f8466',
#       'ac84325a-8e6d-42f1-8554-03c694a61da6',
#       'c5c3ad64-0dc0-4950-b95b-87aae41468ee',
#       '526c87e2-cb87-49a2-8365-b0b03837a724',
#       'c14f4d77-6776-47d8-914c-a7f55717e59d',
#       '0bfa1f3b-5262-4b75-91b0-f9fd722dbf57',
#       '9c38d843-ee0a-465c-a479-1fafd1874090',
#       '3aea6d10-92ad-4ee9-bdab-ccb5112f6836',
#       '3e067dad-aa9e-4cf9-a7ef-2f50db15f0fe',
#       '71ec7f47-1e15-403e-b3a1-4b52cfe65d00',
#       '36b04bbc-1740-4c07-8100-bdda0d9948eb',
#       'd353fc49-3016-479a-8291-70da6ecc6a0d',
#       '9b6a0479-2cfa-4c97-9612-310886a59665',
#       'e1b5d7e4-9852-4008-92af-e0fe1204c97c',
#       '056b34c1-a41c-4b2a-9311-585721d2f3ef',
#       '838fc0ed-3058-40e3-890e-987e5904ea58',
#       '50914d16-a0a3-4042-a386-0bd6574c6320',
#       '409409b1-fe66-4874-80cc-0e44785f07c9',
#       'e252cfd5-c982-4dee-9b7f-bbe1ad3776d2',
#       '64228c9f-2ab1-4883-a9f1-33a9672503bf',
#       '43587dd9-82ce-4233-a1a7-41dafbc0dc76']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 98
}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 98.26396942138672,
#    'Text': 'To the top',
#    'Geometry': {'BoundingBox': {'Width': 0.06382673978805542,
#      'Height': 0.013595044612884521,
#      'Left': 0.7873227596282959,
#      'Top': 0.5662292838096619},
#     'Polygon': [{'X': 0.7873227596282959, 'Y': 0.5662292838096619},
#      {'X': 0.8511494994163513, 'Y': 0.5662292838096619},
#      {'X': 0.8511494994163513, 'Y': 0.5798243284225464},
#      {'X': 0.7873227596282959, 'Y': 0.5798243284225464}]},
#    'Id': 'b031eb3d-df04-4ede-8c80-983ebd5ca563',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['117e300b-2337-4e96-bfc2-18d09c8943a9',
#       '0816eefb-ebc1-4065-8198-56baffde870d',
#       '6b6cfafd-5ca6-429c-b220-4d6d60f1dd85']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 98.9938735961914,
#    'Text': 'Add headers and footers, with an open document',
#    'Geometry': {'BoundingBox': {'Width': 0.4869401454925537,
#      'Height': 0.01957845129072666,
#      'Left': 0.08619745820760727,
#      'Top': 0.600859522819519},
#     'Polygon': [{'X': 0.08619745820760727, 'Y': 0.600859522819519},
#      {'X': 0.5731375813484192, 'Y': 0.600859522819519},
#      {'X': 0.5731375813484192, 'Y': 0.6204379796981812},
#      {'X': 0.08619745820760727, 'Y': 0.6204379796981812}]},
#    'Id': '0eb43fc2-fa7f-4cc5-a2c1-390ac05e2d61',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['359e9be5-ab0c-41a0-9af0-27ed84d13aa0',
#       '1ef034c1-0ad1-4149-96cb-8a8a739b097b',
#       'c448fb0c-4ef0-4988-bd21-91015c468472',
#       'd9611e4c-2434-4f15-a3c3-56fdebfa7d60',
#       '96e94b80-cf01-4866-b7da-afad352f3728',
#       '7e7b351e-6793-438d-9766-f68776c5057f',
#       'ad78eb5b-d432-462a-bf2a-0ed625e32398',
#       '1b8cbbd1-6d4d-4ca4-a686-b4ea24ceb828']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 97.7877426147461,
#    'Text': '1. Open the PDF file to which you want to add the header and footer.',
#    'Geometry': {'BoundingBox': {'Width': 0.5006617903709412,
#      'Height': 0.0163547582924366,
#      'Left': 0.10915277153253555,
#      'Top': 0.6359279751777649},
#     'Polygon': [{'X': 0.10915277153253555, 'Y': 0.6359279751777649},
#      {'X': 0.6098145246505737, 'Y': 0.6359279751777649},
#      {'X': 0.6098145246505737, 'Y': 0.65228271484375},
#      {'X': 0.10915277153253555, 'Y': 0.65228271484375}]},
#    'Id': '6b6f0d8d-8967-4e2c-9a7d-e21398a75012',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['ebe4d623-7d86-4555-b4e1-047934cf8769',
#       '4ca91c98-5817-41a0-aa6e-95171cb67caa',
#       'f0a14866-df09-414a-b11f-191b08d4f84e',
#       '59f9bf01-d27f-4668-82ed-a57a9d6a5ad4',
#       '292abb11-9292-461f-90e4-0fd295773ad3',
#       'b5334b12-39c9-4f9b-96cf-77317f2d1463',
#       'dc6dc4f4-e499-48d5-882d-3fc2c91dc079',
#       '26d7d061-af08-4a1c-88f7-06aa13e9163a',
#       'd008efbd-e07e-4e05-b75a-59e84dc9ddec',
#       'f56e909c-2156-4016-811b-2e15dd74da45',
#       'f427e1d4-5c39-424b-be8e-645b2a0686bd',
#       '4bbfe917-2469-48f0-b2a5-dcae2df203c0',
#       'fbd71689-41be-46d5-b074-7a4369031515',
#       'ad36acd8-b828-4059-9b0f-af58728b37eb',
#       'd7854553-52ae-4767-88a5-6fe7cdd54c92']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 98.31029510498047,
#    'Text': '2. Choose Tools Edit PDF.',
#    'Geometry': {'BoundingBox': {'Width': 0.20181818306446075,
#      'Height': 0.015027077868580818,
#      'Left': 0.10750539600849152,
#      'Top': 0.6683836579322815},
#     'Polygon': [{'X': 0.10750539600849152, 'Y': 0.6683836579322815},
#      {'X': 0.30932357907295227, 'Y': 0.6683836579322815},
#      {'X': 0.30932357907295227, 'Y': 0.6834107041358948},
#      {'X': 0.10750539600849152, 'Y': 0.6834107041358948}]},
#    'Id': '6f92ca50-f1bd-4fbc-9839-ead84440b70b',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['ee094071-b3d7-4223-9520-2e1d0e1c22b7',
#       'af222fdd-62c1-4c83-89a0-85f448a6f03c',
#       'a70b1265-8139-4c00-b361-4c418bed6fe5',
#       'dd30c940-dcd8-44bb-a6bf-cc237caf1456',
#       '844173be-3076-42ab-ab9b-e70af54f4b36']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 99.03539276123047,
#    'Text': 'The Edit PDF toolset is displayed in the secondary toolbar.',
#    'Geometry': {'BoundingBox': {'Width': 0.4249172806739807,
#      'Height': 0.016472389921545982,
#      'Left': 0.12306031584739685,
#      'Top': 0.694979727268219},
#     'Polygon': [{'X': 0.12306031584739685, 'Y': 0.694979727268219},
#      {'X': 0.5479776263237, 'Y': 0.694979727268219},
#      {'X': 0.5479776263237, 'Y': 0.7114521265029907},
#      {'X': 0.12306031584739685, 'Y': 0.7114521265029907}]},
#    'Id': '4294d1f3-0d1b-49e6-b7d8-2e1a11cbe163',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['b12f07b1-b754-422e-b1dd-d31c882ee329',
#       '7a6ffb9b-cc17-4eba-80a5-336825fa1612',
#       'ab0671d1-060d-4231-b728-80636477e7ea',
#       '5dc8b227-f18e-4e4f-af1e-a8e1261fc2ba',
#       'e2351f06-d0d0-4d51-b177-58ba7f449339',
#       '30edad55-56cd-4666-9ca7-ff0f25f40f3f',
#       '4795f73d-9d90-428f-b493-1be68a06230a',
#       '00879a4b-7950-4df9-9fe6-2216bafcbf3c',
#       'f775596a-a114-46aa-915d-3f290fe0b8ef',
#       '58956fcf-8146-4150-925b-9f94f686cfd7']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 98.83650970458984,
#    'Text': 'Note: Formatting and other related options are displayed in the right-hand pane.',
#    'Geometry': {'BoundingBox': {'Width': 0.5739662647247314,
#      'Height': 0.01687714457511902,
#      'Left': 0.12293698638677597,
#      'Top': 0.7257150411605835},
#     'Polygon': [{'X': 0.12293698638677597, 'Y': 0.7257150411605835},
#      {'X': 0.6969032287597656, 'Y': 0.7257150411605835},
#      {'X': 0.6969032287597656, 'Y': 0.7425921559333801},
#      {'X': 0.12293698638677597, 'Y': 0.7425921559333801}]},
#    'Id': 'cc47dc0e-3792-4959-947e-e46405c38c70',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': 
}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 98.73359680175781,
#    'Text': 'The text properties apply to all header and footer entries that are part of this setting definition. You',
#    'Geometry': {'BoundingBox': {'Width': 0.7198466658592224,
#      'Height': 0.016893494874238968,
#      'Left': 0.12297892570495605,
#      'Top': 0.8212595582008362},
#     'Polygon': [{'X': 0.12297892570495605, 'Y': 0.8212595582008362},
#      {'X': 0.8428255915641785, 'Y': 0.8212595582008362},
#      {'X': 0.8428255915641785, 'Y': 0.838153064250946},
#      {'X': 0.12297892570495605, 'Y': 0.838153064250946}]},
#    'Id': '5928bbc4-3f40-4b16-b184-26c7a0eab38d',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['4287cff7-2dc0-4171-83c5-89b6f5c0e13d',
#       'dfea530e-1be5-4cce-b9e4-916d8fa4022e',
#       '2104cb3c-4692-4558-93c3-e21a5232515a',
#       '1365a51a-b9d3-4f45-b6af-3a16340d1a01',
#       'bd96b85a-ccaa-4b63-b7cc-ffff0cfcabf4',
#       '744a20b1-f962-4531-973d-08af4bfaf4a9',
#       '8dab108e-50f9-4087-8662-fca08d482f9d',
#       'aa30ed8f-12c7-49f5-8e7d-4b27ee372305',
#       '786ee38d-0328-44ab-ac17-c5bbc42fe03a',
#       '713c64e8-a344-47d4-a9f0-baaaa85b920f',
#       '0c1ea575-a162-4e99-8969-139b3812c390',
#       '93b2d928-1c48-4c5f-bebc-1a311d0799d7',
#       '33be6ddc-04d8-442c-a678-921e5304ad61',
#       '7b8265fd-f5dc-42d6-8031-afe251437b47',
#       '95bec9d3-536f-4881-a688-a86bcd8923c8',
#       '3a834278-5486-4fdc-a009-ef945fea0158',
#       '3c05071c-7a67-4b4e-a5e3-1b1e2b948862',
#       '01551c9a-9906-481b-bd27-ee0906b2f9ac']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 98.7660140991211,
#    'Text': 'cannot apply different settings to individua header or footer text boxes within the same session in the',
#    'Geometry': {'BoundingBox': {'Width': 0.7449861168861389,
#      'Height': 0.015432646498084068,
#      'Left': 0.12347567826509476,
#      'Top': 0.8398544788360596},
#     'Polygon': [{'X': 0.12347567826509476, 'Y': 0.8398544788360596},
#      {'X': 0.8684618473052979, 'Y': 0.8398544788360596},
#      {'X': 0.8684618473052979, 'Y': 0.8552871346473694},
#      {'X': 0.12347567826509476, 'Y': 0.8552871346473694}]},
#    'Id': '91f6d6bd-7634-4d42-baa9-cbf84a8bd721',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['ac217e86-a6f5-4e36-98f9-d63f70735fd9',
#       '3a0fcf08-14ff-4a3c-b4be-ec01e58ac2f4',
#       '6f167b1e-3bdb-4841-bbdc-255c37363c69',
#       'f6a1751a-6150-4f3e-9494-a38ecaf61359',
#       '7e39189c-6ab7-4609-951d-4823282ef32a',
#       'e50a4443-1ac5-4ea2-a5aa-9653b16b6cd5',
#       '0908e8d5-7615-4f2e-90b2-e5aac47c15ee',
#       '214d6326-eefb-4a2e-b346-8a81a29a13d4',
#       '40f5d2a9-caef-49f9-a7ec-f32b645dbdeb',
#       '88cad9af-286a-4467-bb68-5bd48993c4d7',
#       '262a8758-44d9-40ff-889e-f2ef7dc14239',
#       'dfcc7778-0b0d-4fee-8498-7ca6a2f6ab37',
#       '81e5dfad-75ac-4620-a4ad-d6983e68529c',
#       'c571da13-231e-4518-bf45-3e1d1492e545',
#       '78281512-83af-499d-b2be-40f3c5ee403b',
#       '6f07619e-feb8-40bf-b236-54e47ff5394c',
#       'd42da581-769a-46f1-81d2-e9b6c2638b2d']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 98.98090362548828,
#    'Text': 'Add Header And Footer dialog box',
#    'Geometry': {'BoundingBox': {'Width': 0.26274290680885315,
#      'Height': 0.016811080276966095,
#      'Left': 0.12273542582988739,
#      'Top': 0.8568815588951111},
#     'Polygon': [{'X': 0.12273542582988739, 'Y': 0.8568815588951111},
#      {'X': 0.38547831773757935, 'Y': 0.8568815588951111},
#      {'X': 0.38547831773757935, 'Y': 0.8736926913261414},
#      {'X': 0.12273542582988739, 'Y': 0.8736926913261414}]},
#    'Id': 'd10f8f79-e2e1-4fbb-b357-5bddc3a9ecaf',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['cf7588cc-6e0e-4158-bc79-38f1010bc898',
#       '7af71cd7-9e56-476f-bd7f-5ea054ea7244',
#       '56464e8c-bf7f-42c6-a72a-8aff41f00f67',
#       'ddeca75c-bbfd-4a42-b00e-b9064362d67a',
#       '1c69d6b1-63a5-42b0-a90f-6f0a8278444c',
#       '5771868c-278c-491f-8cb1-db5b48825cae']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 98.09327697753906,
#    'Text': 'To prevent overlapping, click the Appearance Options link and select Shrink Document To Avoid',
#    'Geometry': {'BoundingBox': {'Width': 0.6672713756561279,
#      'Height': 0.016794433817267418,
#      'Left': 0.14993882179260254,
#      'Top': 0.8878788352012634},
#     'Polygon': [{'X': 0.14993882179260254, 'Y': 0.8878788352012634},
#      {'X': 0.8172101974487305, 'Y': 0.8878788352012634},
#      {'X': 0.8172101974487305, 'Y': 0.9046732783317566},
#      {'X': 0.14993882179260254, 'Y': 0.9046732783317566}]},
#    'Id': '49dc4f99-c119-4f7a-9c88-5416e054b3d6',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['86760e3e-26f8-4c11-bde2-9d0a66bd5c58',
#       'fcb5781c-95ec-45f9-9e54-44681d1746f9',
#       '92324ad9-6379-4576-9fd1-68d8155f7810',
#       '66202cdc-c26e-4889-9abe-c610fc2e8dba',
#       '8e51a2d2-1767-4a94-bfc9-37f2e419c910',
#       '9b332cb0-0c46-4f04-9124-e4a543c28176',
#       '4a24194d-7689-4a1c-a5c5-97c84d831398',
#       'da44a53e-fc38-4266-921c-7dd81f9c201a',
#       '3b7265cc-9d13-49bd-b7a9-23c8194f66c3',
#       '8ec5c7bf-03c3-484d-90a0-9da965e8a46b',
#       '6885c8b8-7fd9-42cb-8cff-e4417972c448',
#       '0f1913be-9eaf-4c0a-83ba-d3bb003656ca',
#       '23a1a1ea-176c-4d63-90e5-eea6d8ba27b4',
#       'a8577668-b10f-441e-a520-797ec2de6db8']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 98.7874984741211,
#    'Text': "Overwriting The Document's Text And Graphics. To prevent resizing or repositioning when printing the",
#    'Geometry': {'BoundingBox': {'Width': 0.7164885401725769,
#      'Height': 0.016365041956305504,
#      'Left': 0.14958441257476807,
#      'Top': 0.9064437747001648},
#     'Polygon': [{'X': 0.14958441257476807, 'Y': 0.9064437747001648},
#      {'X': 0.866072952747345, 'Y': 0.9064437747001648},
#      {'X': 0.866072952747345, 'Y': 0.922808825969696},
#      {'X': 0.14958441257476807, 'Y': 0.922808825969696}]},
#    'Id': '8bd51b33-6582-4b59-9412-ab12f4ad0d31',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['42893227-66f4-4396-9f90-10fdc894f87c',
#       'cb2a0d8d-ddc8-454b-9d59-2ed2b4d6f13b',
#       '92e65c80-6261-416e-b2c4-c6400b71168c',
#       '09d61dfe-58f7-4619-9798-5184c96f5b46',
#       '5202c911-6200-469c-8893-d2646e9a3f63',
#       '769d4d08-7f11-4618-9576-c0f80fa6fe33',
#       'bd9e6739-f45b-487e-adc1-ad567813fb8e',
#       'bf2f6956-df53-4393-8110-a7b36bf3cddb',
#       '0d3a71e6-c87b-412a-857f-4e2dfca36a01',
#       'f142f35a-bf85-4d83-a3c0-a00837104f41',
#       '5818e4c1-c84b-4802-9257-67d0cee830b1',
#       'b3044d4b-0820-4728-9f0e-b6a390dc8c86',
#       '589987a2-f3fc-445d-b682-db18ea03b912',
#       'acf8562d-c46c-43d0-973c-d5816ed5e433']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 97.9249267578125,
#    'Text': 'PDF',
#    'Geometry': {'BoundingBox': {'Width': 0.028866564854979515,
#      'Height': 0.01414254866540432,
#      'Left': 0.149515762925148,
#      'Top': 0.9252281785011292},
#     'Polygon': [{'X': 0.149515762925148, 'Y': 0.9252281785011292},
#      {'X': 0.17838232219219208, 'Y': 0.9252281785011292},
#      {'X': 0.17838232219219208, 'Y': 0.9393706917762756},
#      {'X': 0.149515762925148, 'Y': 0.9393706917762756}]},
#    'Id': '007adb75-0387-4502-ae20-35154d52afcf',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['d896cbb3-b242-45e5-bd97-4a5cbb3a3e95']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 96.9968490600586,
#    'Text': 'in large format, select Keep Position And Size Of Header/Footer Text Constant When Printing On',
#    'Geometry': {'BoundingBox': {'Width': 0.6743865013122559,
#      'Height': 0.015785319730639458,
#      'Left': 0.18274712562561035,
#      'Top': 0.9248940348625183},
#     'Polygon': [{'X': 0.18274712562561035, 'Y': 0.9248940348625183},
#      {'X': 0.8571336269378662, 'Y': 0.9248940348625183},
#      {'X': 0.8571336269378662, 'Y': 0.9406793713569641},
#      {'X': 0.18274712562561035, 'Y': 0.9406793713569641}]},
#    'Id': '6edbef23-7ac5-43d2-94a5-19fa9c6a9b58',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['f8b2ab9a-2ad7-44ce-af28-f9a4e2f60e5f',
#       'fcb6709c-580e-46e4-bdcd-1f6187c8c13a',
#       'd016e6b5-263b-45a8-8e52-93bf4d127c93',
#       '96d16476-602a-4426-ad65-a9de71503d6f',
#       '583a60fa-013b-49c9-a881-f47d3b37e58e',
#       'fc0ef7ad-efcf-4cec-b751-98706df1bc7a',
#       'd572bc90-9ac5-4233-99b6-2212a223ac3b',
#       '1be8254f-08f4-41c8-a0fc-cd8d8d50a985',
#       '682b2a5a-3e72-4fd8-aaac-4c9a3e2675bb',
#       '548378e8-9958-4c65-9425-4a8ea6d2482f',
#       '9f7c4ab6-4975-4b66-bebc-94f046c40e5c',
#       '6b75d805-41c1-4956-b337-ac29f95fb5d8',
#       '5846d4c3-e2e3-4803-9e0e-0bc1c771f119',
#       '2a373716-7f0b-47cc-bf38-761063e7ca35',
#       '49e83e77-10d9-4123-8be9-7214f8f77af3']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 98.38375091552734,
#    'Text': 'Different Page Sizes.',
#    'Geometry': {'BoundingBox': {'Width': 0.14087575674057007,
#      'Height': 0.01670173369348049,
#      'Left': 0.1486901193857193,
#      'Top': 0.9422460794448853},
#     'Polygon': [{'X': 0.1486901193857193, 'Y': 0.9422460794448853},
#      {'X': 0.28956589102745056, 'Y': 0.9422460794448853},
#      {'X': 0.28956589102745056, 'Y': 0.9589478373527527},
#      {'X': 0.1486901193857193, 'Y': 0.9589478373527527}]},
#    'Id': '6bab3f2e-889c-457c-a7b9-ccccc5f6ec0d',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['13d7fbdb-23cc-4bfd-a445-8aabe457b438',
#       '425286ec-715a-49cb-ad78-0445475f051a',
#       'c8cdc2c3-7c50-44ca-a483-c80ab81c98fc']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 85.4716796875,
#    'Text': 'htpshelpxadobe.comlacrobatusingadd-headers-iooters-pdishim|',
#    'Geometry': {'BoundingBox': {'Width': 0.3757365942001343,
#      'Height': 0.012063654139637947,
#      'Left': 0.04360581189393997,
#      'Top': 0.9687853455543518},
#     'Polygon': [{'X': 0.04360581189393997, 'Y': 0.9687853455543518},
#      {'X': 0.41934239864349365, 'Y': 0.9687853455543518},
#      {'X': 0.41934239864349365, 'Y': 0.980849027633667},
#      {'X': 0.04360581189393997, 'Y': 0.980849027633667}]},
#    'Id': '625ac1b5-ee97-448b-ae4b-32ca568e5367',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['e1381f9e-bff8-4501-92b0-2dbcf6298e63']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 97.8077621459961,
#    'Text': '2/6',
# ...
#      'Left': 0.08726262301206589,
#      'Top': 0.7341074347496033},
#     'Polygon': [{'X': 0.08726262301206589, 'Y': 0.7341074347496033},
#      {'X': 0.5766040682792664, 'Y': 0.7341074347496033},
#      {'X': 0.5766040682792664, 'Y': 0.7508818507194519},
#      {'X': 0.08726262301206589, 'Y': 0.7508818507194519}]},
#    'Id': '35341d7e-653c-4f6f-ad5e-9051a4c85b67',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['98392d88-f27d-4284-9aef-ca4d47277db9',
#       '225015e9-bd90-40d9-a708-56d0604dc8e8',
#       'e2f9dc76-4a02-4001-a55b-fe1a2937176a',
#       '0f6681bf-51dc-4a65-b15a-851396365712',
#       'b1971c7b-1545-43c6-b538-925113b5863d',
#       'be601b69-c53d-47c8-83d1-c41270ba75a5',
#       '7d5e5839-1b0d-425d-b7c2-91370b441790',
#       '46bccf85-b383-4215-9d76-f92461fa1ca0',
#       'd6153751-9ffa-4ca9-b220-159e653a55e6',
#       '6e6a52bd-9173-47a9-903a-406093d30b0b',
#       '2e7078a2-6151-4b6c-9b87-d6ea99022ece']}],
#    'Page': 2},
#   {'BlockType': 'LINE',
#    'Confidence': 98.85262298583984,
#    'Text': '1. Open the PDF file containing header and footer.',
#    'Geometry': {'BoundingBox': {'Width': 0.3624397814273834,
#      'Height': 0.017867838963866234,
#      'Left': 0.10933737456798553,
#      'Top': 0.7642855048179626},
#     'Polygon': [{'X': 0.10933737456798553, 'Y': 0.7642855048179626},
#      {'X': 0.47177714109420776, 'Y': 0.7642855048179626},
#      {'X': 0.47177714109420776, 'Y': 0.782153308391571},
#      {'X': 0.10933737456798553, 'Y': 0.782153308391571}]},
#    'Id': '25fa05de-8909-424a-86f3-339f4cb0ed3d',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['713f9f1e-aa61-4acd-876b-9fca02685208',
#       '979d3545-7f6d-4df2-bd4e-52070fdf06de',
#       '1e107328-3048-4a28-ad7f-e89093b16de3',
#       '9010cb21-d779-462b-ba36-e9b13c38c254',
#       'b2b786e9-aff0-4bac-9e40-b00a35939574',
#       '7b56f2ee-2c9d-490a-8835-9dfa4a043d97',
#       '45dafe32-0527-4c99-9f9c-98433a8468bc',
#       'ef9392da-306c-460f-99d4-d3c86ebc5da5',
#       '8c627da1-e4e7-47d1-b6cb-1376728330ea']}],
#    'Page': 2},
#   {'BlockType': 'LINE',
#    'Confidence': 97.32064819335938,
#    'Text': '2. Choose Tools Edit PDF.',
#    'Geometry': {'BoundingBox': {'Width': 0.20133525133132935,
#      'Height': 0.01534431241452694,
#      'Left': 0.10733693093061447,
#      'Top': 0.7975205183029175},
#     'Polygon': [{'X': 0.10733693093061447, 'Y': 0.7975205183029175},
#      {'X': 0.3086721897125244, 'Y': 0.7975205183029175},
#      {'X': 0.3086721897125244, 'Y': 0.8128647804260254},
#      {'X': 0.10733693093061447, 'Y': 0.8128647804260254}]},
#    'Id': 'a7d6af52-6624-4644-94c8-6fe132086447',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['bc586492-b951-44ec-8c1a-2b42aa1f01cb',
#       '1b389839-d1d2-4def-97ae-cc149fd592b2',
#       'e4dbcc0e-0f35-44a3-a00f-fa729d3f7d3e',
#       'b40046a3-cd84-465f-bcbd-3994cfc859c0',
#       '0fa25af2-74d7-4ca8-a75d-7d04659827b5']}],
#    'Page': 2},
#   {'BlockType': 'LINE',
#    'Confidence': 99.14340209960938,
#    'Text': '3. In the secondary toolbar, choose Header & Footer Update.',
#    'Geometry': {'BoundingBox': {'Width': 0.46101588010787964,
#      'Height': 0.016063565388321877,
#      'Left': 0.10781285911798477,
#      'Top': 0.8296954035758972},
#     'Polygon': [{'X': 0.10781285911798477, 'Y': 0.8296954035758972},
#      {'X': 0.5688287615776062, 'Y': 0.8296954035758972},
#      {'X': 0.5688287615776062, 'Y': 0.8457589745521545},
#      {'X': 0.10781285911798477, 'Y': 0.8457589745521545}]},
#    'Id': '379e516b-bc2a-4d47-a1c6-6fd3da4ef5bb',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['ff83ddcc-55cd-4f8d-a5eb-07ca6e661913',
#       '7c90bdc3-1bb1-4c89-9b83-dbc34742a7a1',
#       '78a3cb1e-9462-48e7-bd4b-a62d766fa067',
#       '4c0d8c58-a1f6-4e4f-bae0-557027a7f112',
#       'f09cde74-6c6d-4c60-81a1-518325e61915',
#       '7d215fed-622e-406d-9a96-1ab78e207135',
#       '989c2fed-265e-4330-a6b2-b1895724ba3e',
#       '603c4527-0429-4f89-802f-538d2aa3e714',
#       '0a2cac10-dba4-4591-bdcd-160420e8d909',
#       '6bf9e5c2-42ef-4009-b0f8-6feabd6ddb43']}],
#    'Page': 2},
#   {'BlockType': 'LINE',
#    'Confidence': 98.66915130615234,
#    'Text': '4. Change the settings as needed.',
#    'Geometry': {'BoundingBox': {'Width': 0.24264763295650482,
#      'Height': 0.018832119181752205,
#      'Left': 0.10639035701751709,
#      'Top': 0.8599764108657837},
#     'Polygon': [{'X': 0.10639035701751709, 'Y': 0.8599764108657837},
#      {'X': 0.3490380048751831, 'Y': 0.8599764108657837},
#      {'X': 0.3490380048751831, 'Y': 0.8788084983825684},
#      {'X': 0.10639035701751709, 'Y': 0.8788084983825684}]},
#    'Id': '967f8ea6-edca-4136-bde0-52ff2059e8e3',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['c3c45ea6-e1ea-4f10-af81-62e57385444a',
#       '0a55a6d3-8749-4bde-8ccb-21a387936dd3',
#       '994c5497-860e-4b6d-99a1-607f2eed8be8',
#       'b3842b43-5a09-4178-9d2f-f38709cf1341',
#       '2b07ccb3-a8d1-4532-afe0-03f852fc5e7b',
#       'b141f049-bd78-4d0e-b329-e7e3c0b1492d']}],
#    'Page': 2},
#   {'BlockType': 'LINE',
#    'Confidence': 97.76951599121094,
#    'Text': 'To the top',
#    'Geometry': {'BoundingBox': {'Width': 0.06423407047986984,
#      'Height': 0.013966619037091732,
#      'Left': 0.7869868278503418,
#      'Top': 0.8952924609184265},
#     'Polygon': [{'X': 0.7869868278503418, 'Y': 0.8952924609184265},
#      {'X': 0.8512209057807922, 'Y': 0.8952924609184265},
#      {'X': 0.8512209057807922, 'Y': 0.9092590808868408},
#      {'X': 0.7869868278503418, 'Y': 0.9092590808868408}]},
#    'Id': '0713a59f-65b0-4736-8ce0-61bfa929b76c',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['8199f52e-4dc9-44cd-b825-0c2815734710',
#       'a9a4db27-1855-48fb-bb8b-8430906cd83c',
#       'ac1a26a7-83b4-4b0e-a315-cef3c05b2f31']}],
#    'Page': 2},
#   {'BlockType': 'LINE',
#    'Confidence': 99.18478393554688,
#    'Text': 'Add another header and footer',
#    'Geometry': {'BoundingBox': {'Width': 0.30375757813453674,
#      'Height': 0.019267577677965164,
#      'Left': 0.08653004467487335,
#      'Top': 0.9305419325828552},
#     'Polygon': [{'X': 0.08653004467487335, 'Y': 0.9305419325828552},
#      {'X': 0.3902876079082489, 'Y': 0.9305419325828552},
#      {'X': 0.3902876079082489, 'Y': 0.9498094916343689},
#      {'X': 0.08653004467487335, 'Y': 0.9498094916343689}]},
#    'Id': '45426be3-c2bb-43a2-b990-15dc4f8717d6',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['e0d58704-bff6-4f4e-82b2-863cd3ac3ce5',
#       '4cce750b-f6d4-41b4-9007-728f3be16fae',
#       '5bd6bb5c-eda5-4fc0-8b53-55ed854ea417',
#       '3d91071f-8df0-432b-93a4-e615caafb1bd',
#       'a749c750-2848-4074-8261-656247fee29f']}],
#    'Page': 2},
#   {'BlockType': 'LINE',
#    'Confidence': 87.11627960205078,
#    'Text': 'tpshelpxadobe.comlacrobatlusingadctheaders-iooters-pdishtm|',
#    'Geometry': {'BoundingBox': {'Width': 0.3665897846221924,
#      'Height': 0.011486150324344635,
#      'Left': 0.0536096915602684,
#      'Top': 0.9687830209732056},
#     'Polygon': [{'X': 0.0536096915602684, 'Y': 0.9687830209732056},
#      {'X': 0.4201994836330414, 'Y': 0.9687830209732056},
#      {'X': 0.4201994836330414, 'Y': 0.9802691340446472},
#      {'X': 0.0536096915602684, 'Y': 0.9802691340446472}]},
#    'Id': '2687d7e0-c41d-4c18-86ad-e9f9fb21f82d',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['289a5b92-737c-48d1-86ab-56fc582f42bf']}],
#    'Page': 2},
#   {'BlockType': 'LINE',
#    'Confidence': 97.71296691894531,
#    'Text': '3/6',
#    'Geometry': {'BoundingBox': {'Width': 0.01642635650932789,
#      'Height': 0.010828450322151184,
#      'Left': 0.9407780766487122,
#      'Top': 0.9688506722450256},
#     'Polygon': [{'X': 0.9407780766487122, 'Y': 0.9688506722450256},
#      {'X': 0.9572044610977173, 'Y': 0.9688506722450256},
#      {'X': 0.9572044610977173, 'Y': 0.9796791672706604},
#      {'X': 0.9407780766487122, 'Y': 0.9796791672706604}]},
#    'Id': 'b0265a11-558f-4a3f-935c-7383133dcf4c',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': 

#    'Page': 2},
#   {'BlockType': 'WORD',
#    'Confidence': 87.3459701538086,
#    'Text': 's.',
#    'Geometry': {'BoundingBox': {'Width': 0.01134540606290102,
#      'Height': 0.014086331240832806,
#      'Left': 0.10775472223758698,
#      'Top': 0.04687095806002617},
#     'Polygon': [{'X': 0.10775472223758698, 'Y': 0.04687095806002617},
#      {'X': 0.11910012364387512, 'Y': 0.04687095806002617},
#      {'X': 0.11910012364387512, 'Y': 0.06095729023218155},
#      {'X': 0.10775472223758698, 'Y': 0.06095729023218155}]},
#    'Id': '2231cf19-f4cb-4f78-b9b7-fb0f21fc34d8',
#    'Page': 2},
#   {'BlockType': 'WORD',
#    'Confidence': 98.48954010009766,
#    'Text': 'Type',
#    'Geometry': {'BoundingBox': {'Width': 0.03534284979104996,
#      'Height': 0.01702188141644001,
#      'Left': 0.12308365106582642,
#      'Top': 0.04541897028684616},
#     'Polygon': [{'X': 0.12308365106582642, 'Y': 0.04541897028684616},
#      {'X': 0.15842650830745697, 'Y': 0.04541897028684616},
#      {'X': 0.15842650830745697, 'Y': 0.06244084984064102},
#      {'X': 0.12308365106582642, 'Y': 0.06244084984064102}]},
#    'Id': '3304acab-0d19-4418-9534-84680a8579e5',
#    'Page': 2},
#   {'BlockType': 'WORD',
#    'Confidence': 99.09757995605469,
#    'Text': 'the',
#    'Geometry': {'BoundingBox': {'Width': 0.023258151486516,
#      'Height': 0.014349457807838917,
#      'Left': 0.1630331128835678,
#      'Top': 0.04637540876865387},
#     'Polygon': [{'X': 0.1630331128835678, 'Y': 0.04637540876865387},
#      {'X': 0.18629126250743866, 'Y': 0.04637540876865387},
#      {'X': 0.18629126250743866, 'Y': 0.06072486564517021},
#      {'X': 0.1630331128835678, 'Y': 0.06072486564517021}]},
#    'Id': '1a9e6477-b600-4bf0-9c28-9eb6db8e58ea',
#    'Page': 2}],
#  'ResponseMetadata': {'RequestId': 'bb9c4326-3488-442a-8469-c6540494779f',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Fri, 26 Apr 2019 18:09:26 GMT',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '272180',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'bb9c4326-3488-442a-8469-c6540494779f'},
#   'RetryAttempts': 0}}

# %%
discarded_header = []
discarded_footer = []
saved_text = []

for block in blocks:
    if (block['BlockType'] == 'PAGE'):
        print('Page: {}'.format(block['Page']))
    elif (block['BlockType'] == 'LINE'):
        text = block['Text']
        top = block['Geometry']['BoundingBox']['Top']
        polygon_bottom = block['Geometry']['Polygon'][2]['Y']
        polygon_top    = block['Geometry']['Polygon'][0]['Y']
        if (polygon_bottom < 0.035):
            discarded_header.append(text)
        elif (polygon_top > 0.95):
            discarded_footer.append(text)
        else:
            saved_text.append(text)

print('\nDiscarded headers:')
for h in discarded_header:
    print(h)
print('\nDiscarded footers:')
for f in discarded_footer:
    print(f)
    
print('\nSaved text:')
for s in saved_text:
    print(s)
# Out:
# Page: 1
# Page: 2
#
# Discarded headers:
# 5/9/2016
# Add headers, footers, and Bates numbering to PDFs, Adobe Acrobat
# 5/9/2016
# Add dheaders, footers, and Bates numbering to PDFs, Adobe Acrobat
#
# Discarded footers:
# htpshelpxadobe.comlacrobatusingadd-headers-iooters-pdishim|
# 2/6
# tpshelpxadobe.comlacrobatlusingadctheaders-iooters-pdishtm|
# 3/6
#
# Saved text:
# Headers, footers, and Bates numbering
# Add headers and footers, with an open document
# Add headers and footers, with no document open (Windows only)
# Update the headers and footers
# Add another header and footer
# Replace all headers and footers
# Remove all headers and footers
# Show all
# To the top
# Headers, footers, and Bates numbering
# Acrobat DC lets you add a header and footer throughout a PDF. Headers and footers can include a date,
# automatic page numbering, Bates numbers for legal documents, or the title and author. You can add
# headers and footers to one or more PDFS.
# You can vary the headers and footers within a PDF. For example, you can add a header that displays the
# page number on the right side of odd-numbered pages, and another header that displays the page number
# on
# the left side of numbered pages. When adding Bates numbering, you can set the number of digits,
# the starting number, and the prefix or suffix to be appended to each Bates number.
# You can define and save your headers and footers to reuse them later, or you can simply apply a header
# and footer and forget it. After applying a header and footer, you can edit, replace, or delete it in the PDF.
# You can also preview headers and footers before applying them and adjust the header and footer margins
# so that they don't overlap other page content.
# To the top
# Add headers and footers, with an open document
# 1. Open the PDF file to which you want to add the header and footer.
# 2. Choose Tools Edit PDF.
# The Edit PDF toolset is displayed in the secondary toolbar.
# Note: Formatting and other related options are displayed in the right-hand pane.
# 3. In the secondary toolbar, choose Header & Footer Add.
# 4. As needed, specify the Font and Margin values.
# The text properties apply to all header and footer entries that are part of this setting definition. You
# cannot apply different settings to individua header or footer text boxes within the same session in the
# Add Header And Footer dialog box
# To prevent overlapping, click the Appearance Options link and select Shrink Document To Avoid
# Overwriting The Document's Text And Graphics. To prevent resizing or repositioning when printing the
# PDF
# in large format, select Keep Position And Size Of Header/Footer Text Constant When Printing On
# Different Page Sizes.
# s. Type the text in any of the header and footer text boxes. To insert page numbers or the current date,
# click in a box and then click the corresponding buttons. To select formatting for automatic entries,
# click Page Number And Date Format.
# Note: You can combine text with dates and page numbers. You can also add several lines of text to
# an
# entry.
# 6. To specify the pages on which the header and footer appear, click Page Range Options. Then specify
# a page range and choose a Subset option, as needed.
# 7. Examine the results in the Preview area, using the Preview Page option to see different pages of the
# PDF.
# 8. (Optional) To save these header and footer settings for future use, click Save Settings at the top of the
# dialog box.
# 9. (Optional) To apply the same settings to additional PDFS, click Apply To Multiple Files. Click Add
# Files, choose Add Files or Add Open Files, and select the files. Then in the Output Options dialog
# box, specify your folder and filename preferences, and click OK.
# To the top
# Add headers and footers, with no document open (Windows only)
# 1. Choose Tools Edit PDF.
# 2. In the secondary toolbar, choose Header & Footer Add.
# 3. In the dialog box, click Add Files, choose Add Files, then select the files.
# You can also add files or folders by dragging them into the dialog box.
# 4. Follow steps 4 through 8 in the procedure for adding headers and footers with an open document.
# When you have finished setting up your headers and footers, click OK.
# s. In the Output Options dialog box, specify your folder and filename preferences and click OK.
# To the top
# Update the headers and footers
# Updating applies to the most recently added header and footer set.
# 1. Open the PDF file containing header and footer.
# 2. Choose Tools Edit PDF.
# 3. In the secondary toolbar, choose Header & Footer Update.
# 4. Change the settings as needed.
# To the top
# Add another header and footer
